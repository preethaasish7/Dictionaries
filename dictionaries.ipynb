# %%
d1={'a':'some value','b':[1,2,3,4]}
d1
d1[7]='an integer'
d1
d1['b']
# Out:
# [1, 2, 3, 4]

# %%
counts={'name':'asish','dept':'soil','year':'2022'}
for key in counts:
  print(key,counts[key])
# Out:
# name asish
# dept soil
# year 2022

# %%
counts={'name':'asish','dept':'soil','year':'2022'}
for key in counts:
  if counts[key] >10:
  print(key, counts[key])
# Out:
#   File "/tmp/ipython-input-3967241575.py", line 4
#     print(key, counts[key])
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
set([2,2,2,1,3,3])
# Out:
# {1, 2, 3}

# %%
{2,2,2,1,3,3}
# Out:
# {1, 2, 3}

# %%
a={1,2,3,4,5}
b={4,5,6,7,8}
a|b
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
a={1,2,3,4,5}
b={4,5,6,7,8}
a&b
c=a.copy()
c|=b
c
d=a.copy()
d&=b
d
# Out:
# {4, 5}

# %%
my_data=[1,2,3,4]
my_set={tuple(my_data)}
my_set
# Out:
# {(1, 2, 3, 4)}

# %%
my_set={1,2,3,4,5}
{1,2,3}.issubset(a_subset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1989090329.py in <cell line: 0>()
#       1 my_set={1,2,3,4,5}
# ----> 2 {1,2,3}.issubset(a_subset)
#
# NameError: name 'a_subset' is not defined
